# %% [markdown]
# # Pandas Case Study — Sales Store
#
# **Goal:** Practice Pandas using a realistic sales dataset.
#
# This case study is intentionally **solution-free**. The questions focus on extracting business insights rather than basic DataFrame inspection.
#
# ### Rules
# - Use **Pandas only** for the data analysis.
# - You may use `matplotlib` for questions that benefit from visualization.
# - Avoid machine-learning libraries and SQL.
# - Try to solve each question yourself before looking anything up.
# - Some questions intentionally require combining multiple Pandas concepts: `groupby`, aggregation, filtering, sorting, merging, reshaping, datetime operations, ranking, percentages, and multi-level analysis.
# - For questions asking for a result, make the final output clear and readable.
#
# ### Dataset
# File: `sales_store.csv`
#
# Start by loading the dataset and converting the date columns to appropriate datetime types.
#
# **Do not add solutions to this notebook.** Use a separate notebook/script for your answers if you want to keep the question notebook clean.

# %% [markdown]
# ## Question 1
#
# Which 10 customers generated the highest total sales? Return the customer name, customer ID, number of orders, and total sales.
#
# **Your work:**

# %% [markdown]
# ## Question 2
#
# Which states generated the highest total sales, and how concentrated are sales in the top 5 states compared with all other states? Show the top 10 states with their sales and percentage of overall sales.
#
# **Your work:**

# %% [markdown]
# ## Question 3
#
# For each Region, calculate total sales, number of unique customers, number of unique orders, and average sales per order. Which region appears strongest when considering both sales volume and customer reach?
#
# **Your work:**

# %% [markdown]
# ## Question 4
#
# Which Category has the highest sales, and how does each Sub-Category contribute to its parent Category's sales? Rank Sub-Categories within each Category by their share of Category sales.
#
# **Your work:**

# %% [markdown]
# ## Question 5
#
# Find the 10 Product Names with the highest total sales. For each product, show how many unique customers purchased it and in how many unique orders it appeared.
#
# **Your work:**

# %% [markdown]
# ## Question 6
#
# Identify the products that were purchased by the largest number of unique customers. Return the top 10 products and compare their total sales with their customer reach.
#
# **Your work:**

# %% [markdown]
# ## Question 7
#
# Which customers have placed orders in more than one Region? Identify them and calculate their total sales and number of regions served.
#
# **Your work:**

# %% [markdown]
# ## Question 8
#
# For each Ship Mode, calculate total sales, number of unique orders, and average shipping delay in days (Ship Date − Order Date). Which shipping mode has the highest average delay?
#
# **Your work:**

# %% [markdown]
# ## Question 9
#
# Does a longer shipping time appear to be associated with higher or lower sales per order? Create shipping-delay groups (for example, 0–1, 2–3, 4–5, 6+ days) and compare their average order sales.
#
# **Your work:**

# %% [markdown]
# ## Question 10
#
# Find the month with the highest total sales in each year. Return the year, month, and sales, then determine whether the strongest month is consistent across years.
#
# **Your work:**

# %% [markdown]
# ## Question 11
#
# Calculate monthly sales for the entire dataset. Which 3 months have the highest sales and which 3 have the lowest sales? Also calculate each month's share of annual sales.
#
# **Your work:**

# %% [markdown]
# ## Question 12
#
# Compare the Consumer, Corporate, and Home Office segments. For each segment calculate total sales, unique customers, unique orders, average order value, and average sales per customer. Which segment has the strongest customer value?
#
# **Your work:**

# %% [markdown]
# ## Question 13
#
# Find customers whose total sales are above the overall average customer sales. Return the top 20 among those customers and calculate how much of total company sales they represent.
#
# **Your work:**

# %% [markdown]
# ## Question 14
#
# Find customers who placed at least 3 unique orders but have below-average sales per order. What does this tell you about their purchasing behavior?
#
# **Your work:**

# %% [markdown]
# ## Question 15
#
# For every State, calculate total sales and number of unique customers. Identify states with high customer counts but relatively low sales per customer, and states with low customer counts but unusually high sales per customer.
#
# **Your work:**

# %% [markdown]
# ## Question 16
#
# Which City has the highest total sales within each Region? Return the winning city, its region, total sales, unique customers, and unique orders.
#
# **Your work:**

# %% [markdown]
# ## Question 17
#
# Within each Category, identify the Sub-Category with the highest average sales per order and the Sub-Category with the lowest average sales per order. Also show their total sales.
#
# **Your work:**

# %% [markdown]
# ## Question 18
#
# Find the top 10 customers by total sales and determine whether they are concentrated in particular Segments or Regions. Summarize the distribution.
#
# **Your work:**

# %% [markdown]
# ## Question 19
#
# Calculate the percentage of total sales generated by each Product Category for every Region. Which Region has the most different category mix compared with the overall company mix?
#
# **Your work:**

# %% [markdown]
# ## Question 20
#
# For each year, calculate total sales, number of unique customers, number of unique orders, and average order value. Then calculate the year-over-year sales growth rate.
#
# **Your work:**

# %% [markdown]
# ## Question 21
#
# Identify orders containing products from more than one Category. For each such Order ID, calculate total sales and number of Categories. Return the 15 highest-value multi-category orders.
#
# **Your work:**

# %% [markdown]
# ## Question 22
#
# Find the most common combinations of Category and Ship Mode based on unique orders. Which combination generates the most sales, and is that also the most frequently used combination?
#
# **Your work:**

# %% [markdown]
# ## Question 23
#
# For each Sub-Category, calculate total sales, unique customers, unique orders, and average sales per order. Rank Sub-Categories using total sales and compare that ranking with the ranking by average order value. Where do the rankings differ most?
#
# **Your work:**

# %% [markdown]
# ## Question 24
#
# Find customers who purchased products from at least 3 different Categories. Which of these customers generated the highest sales? Return their category count, order count, and total sales.
#
# **Your work:**

# %% [markdown]
# ## Question 25
#
# Determine the top 10 cities by total sales. For each city, calculate its percentage contribution to its Region's sales. Which top-selling city is most dominant within its own region?
#
# **Your work:**

# %% [markdown]
# ## Question 26
#
# For each Order ID, calculate total order sales and number of products (rows). Investigate whether larger orders tend to have higher order values by grouping orders by number of product rows and comparing average order sales.
#
# **Your work:**

# %% [markdown]
# ## Question 27
#
# Find the 10 Product Names with the highest sales in each Region. Ensure the result is ranked separately within each Region, and compare whether the same products appear across multiple regions.
#
# **Your work:**

# %% [markdown]
# ## Question 28
#
# Calculate each customer's first and last order date. Identify customers whose purchasing period (last order date − first order date) spans at least one year, and rank them by total sales.
#
# **Your work:**

# %% [markdown]
# ## Question 29
#
# Build a sales contribution analysis for the hierarchy Region → Category → Sub-Category. For each level, calculate total sales and percentage contribution to its immediate parent. Use this to identify the strongest and weakest parts of the sales hierarchy.
#
# **Your work:**
