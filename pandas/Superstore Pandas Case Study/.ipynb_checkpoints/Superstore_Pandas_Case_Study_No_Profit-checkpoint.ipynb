# %% [markdown]
# # 🛒 Superstore — Pandas Real-World Case Study
#
# **Goal:** Practice Pandas from raw data investigation through business insights using **one real-world dataset**.
#
# ### Rules
# - Use **Pandas only** for analysis.
# - Do **not** use NumPy, Matplotlib, Seaborn, or Scikit-learn for this case study.
# - Do not look up solutions while solving.
# - You decide which Pandas operation is appropriate for each problem.
# - If stuck, ask for a **hint first**, not the solution.
#
# ### Dataset
# Use the Superstore CSV dataset you have already selected.
#
# ### Important
# This version is designed specifically for the dataset you are using, which contains **Sales but does not contain Profit, Quantity, Discount, or Cost columns**.
#
# Therefore, all questions that require those unavailable fields have been removed.
#
# ### Workflow
# `Business Understanding → Inspection → Data Quality → Sales Analysis → Customers → Products → Regions → Time → Shipping → Filtering → New Columns → GroupBy → Pivot Tables → Advanced Analysis → Business Insights`

# %% [markdown]
# ## 1. Business Understanding
#
# Before coding, understand the business problem.
#
# > **Important:** These questions are intentionally simple. The main learning starts from Part 2 onward.

# %% [markdown]
# ### 1. What is this dataset about?
#
# **Your answer:**

# %% [markdown]
# ### 2. What does one row represent?
#
# **Your answer:**

# %% [markdown]
# ### 3. What would the company want to know from this data?
#
# **Your answer:**

# %% [markdown]
# ### 4. What could “sales performance” mean?
#
# **Your answer:**

# %% [markdown]
# ### 5. What could “customer performance” mean?
#
# **Your answer:**

# %% [markdown]
# ### 6. What could “product performance” mean?
#
# **Your answer:**

# %% [markdown]
# ## 2. Load & Inspect the Dataset
#
# You have received the raw dataset from the company. Explore its structure before changing anything.

# %% [markdown]
# ### Q1. Load the CSV into a DataFrame.

# %% [markdown]
# ### Q2. Display the first 5 records.

# %% [markdown]
# ### Q3. Display the last 5 records.

# %% [markdown]
# ### Q4. Find the number of rows and columns.

# %% [markdown]
# ### Q5. Find all column names.

# %% [markdown]
# ### Q6. Determine the datatype of every column.

# %% [markdown]
# ### Q7. Get a statistical summary of numerical columns.

# %% [markdown]
# ### Q8. Find the number of unique values in every column.

# %% [markdown]
# ### Q9. Find the unique values of important categorical columns.

# %% [markdown]
# ### Q10. Determine which columns are numerical and which are categorical.

# %% [markdown]
# ### Your Observations
#
# After completing the inspection, write **5–8 observations or questions** that came from the outputs.
#
# Do not just repeat the commands you ran. Focus on things you noticed about the data.

# %% [markdown]
# ## 3. Data Quality Investigation
#
# Pretend you do not fully trust the raw data yet. Investigate whether the dataset is suitable for analysis.

# %% [markdown]
# ### Q11. Find the number of missing values in every column.

# %% [markdown]
# ### Q12. Find the percentage of missing values in every column.

# %% [markdown]
# ### Q13. Identify columns that contain missing values.

# %% [markdown]
# ### Q14. Investigate whether missing values are concentrated in any particular type of record.

# %% [markdown]
# ### Q15. Check whether duplicate rows exist.

# %% [markdown]
# ### Q16. Find the number of duplicate rows.

# %% [markdown]
# ### Q17. Investigate whether duplicates are exact duplicates or duplicates based on particular identifiers.

# %% [markdown]
# ### Q18. Check whether the date columns have the correct datatype.

# %% [markdown]
# ### Q19. Identify columns whose datatype doesn't make sense for their meaning.

# %% [markdown]
# ## 4. Sales Analysis
#
# Start answering business questions using the Sales column available in the dataset.

# %% [markdown]
# ### Q20. What is the total sales generated?

# %% [markdown]
# ### Q21. What is the average sales value per order/record? Decide whether the question should be interpreted per row or per Order ID.

# %% [markdown]
# ### Q22. What is the highest individual sales value?

# %% [markdown]
# ### Q23. What is the lowest individual sales value?

# %% [markdown]
# ### Q24. What is the median sales value?

# %% [markdown]
# ### Q25. How many records have Sales greater than the overall average Sales?

# %% [markdown]
# ### Q26. What are the top 10 individual sales records?

# %% [markdown]
# ### Q27. What are the bottom 10 individual sales records?

# %% [markdown]
# ### Q28. What percentage of records have Sales below the overall median?

# %% [markdown]
# ## 5. Product Analysis
#
# Management wants to understand which products and product groups are performing well based on Sales.

# %% [markdown]
# ### Q29. How many different product categories exist?

# %% [markdown]
# ### Q30. Find total sales for every category.

# %% [markdown]
# ### Q31. Find average sales for every category.

# %% [markdown]
# ### Q32. Which category has the highest total sales?

# %% [markdown]
# ### Q33. Which category has the lowest total sales?

# %% [markdown]
# ### Q34. Find total sales for every sub-category.

# %% [markdown]
# ### Q35. Find average sales for every sub-category.

# %% [markdown]
# ### Q36. Find the top 5 sub-categories by total sales.

# %% [markdown]
# ### Q37. Find the bottom 5 sub-categories by total sales.

# %% [markdown]
# ### Q38. Find the top 10 individual products based on total Sales.

# %% [markdown]
# ### Q39. Find the products that appear in the largest number of records.

# %% [markdown]
# ### Q40. Identify sub-categories that have high total sales but relatively low average sales per record. Decide how you will investigate this.

# %% [markdown]
# ## 6. Customer Analysis
#
# Some customers may generate much more sales than others. Investigate customer behavior using the available fields.

# %% [markdown]
# ### Q41. How many unique customers exist?

# %% [markdown]
# ### Q42. Find the number of records associated with each customer.

# %% [markdown]
# ### Q43. Find the top 10 customers by total Sales.

# %% [markdown]
# ### Q44. Find the top 10 customers by average Sales per record.

# %% [markdown]
# ### Q45. Find the average total Sales generated per customer.

# %% [markdown]
# ### Q46. Find customers who appear in the largest number of records.

# %% [markdown]
# ### Q47. Find customers who have both a high number of records and high total Sales.

# %% [markdown]
# ### Q48. Compare customer segments based on Sales.

# %% [markdown]
# ## 7. Regional Analysis
#
# The company operates across multiple geographical areas. Investigate differences in Sales performance.

# %% [markdown]
# ### Q49. How many regions are present?

# %% [markdown]
# ### Q50. Calculate total Sales by region.

# %% [markdown]
# ### Q51. Find average Sales by region.

# %% [markdown]
# ### Q52. Find the best-performing region based on total Sales.

# %% [markdown]
# ### Q53. Find the region with the lowest total Sales.

# %% [markdown]
# ### Q54. Find total Sales by state.

# %% [markdown]
# ### Q55. Find the top 10 states by Sales.

# %% [markdown]
# ### Q56. Find the bottom 10 states by Sales.

# %% [markdown]
# ### Q57. Find the number of customers in each region.

# %% [markdown]
# ### Q58. Compare Sales performance across Region × Category.

# %% [markdown]
# ## 8. Time Analysis
#
# Investigate how Sales change over time using Pandas date functionality.

# %% [markdown]
# ### Q59. Convert the relevant date columns into proper Pandas datetime datatypes.

# %% [markdown]
# ### Q60. Extract Year, Month, Day, Day of week, and Quarter into usable information.

# %% [markdown]
# ### Q61. Calculate total Sales by year.

# %% [markdown]
# ### Q62. Calculate average Sales by year.

# %% [markdown]
# ### Q63. Calculate total Sales by month.

# %% [markdown]
# ### Q64. Find the best-performing month based on total Sales.

# %% [markdown]
# ### Q65. Find the worst-performing month based on total Sales.

# %% [markdown]
# ### Q66. Calculate Sales by Year and Month.

# %% [markdown]
# ### Q67. Determine whether Sales are increasing or decreasing over time.

# %% [markdown]
# ### Q68. Find the date with the highest individual Sales.

# %% [markdown]
# ### Q69. Find the number of records for each year.

# %% [markdown]
# ### Q70. Compare Sales across quarters.

# %% [markdown]
# ## 9. Shipping Analysis
#
# Investigate how shipping methods relate to orders and Sales.

# %% [markdown]
# ### Q71. How many different shipping modes exist?

# %% [markdown]
# ### Q72. Find the number of records for each shipping mode.

# %% [markdown]
# ### Q73. Calculate total Sales for each shipping mode.

# %% [markdown]
# ### Q74. Calculate average Sales for each shipping mode.

# %% [markdown]
# ### Q75. Determine which shipping mode generates the most total Sales.

# %% [markdown]
# ### Q76. Compare shipping modes across different regions.

# %% [markdown]
# ## 10. Filtering Practice
#
# Use business conditions to create filtered DataFrames. Choose sensible thresholds where the question intentionally leaves them open.

# %% [markdown]
# ### Q77. Find all transactions where Sales is greater than a sensible threshold you choose.

# %% [markdown]
# ### Q78. Find all transactions where Sales is below a sensible threshold you choose.

# %% [markdown]
# ### Q79. Find transactions belonging to a specific category AND a specific region.

# %% [markdown]
# ### Q80. Find transactions within a specific date range.

# %% [markdown]
# ### Q81. Find the top 20 most expensive individual sales records.

# %% [markdown]
# ### Q82. Find transactions for a specific customer and inspect their purchase records.

# %% [markdown]
# ### Q83. Find transactions where Sales is above the overall average and belongs to a specific category.

# %% [markdown]
# ## 11. Creating New Columns
#
# Create useful derived columns from information that actually exists in this dataset.

# %% [markdown]
# ### Q84. Create a meaningful order-size category based on Sales, such as Low, Medium, and High. Decide the thresholds yourself.

# %% [markdown]
# ### Q85. Create a time-related feature that could be useful for future analysis.

# %% [markdown]
# ### Q86. Create a feature representing the number of days between Order Date and Ship Date.

# %% [markdown]
# ### Q87. Create a feature that identifies whether an order was shipped on the same day it was placed.

# %% [markdown]
# ## 12. GroupBy Challenges
#
# Use multiple dimensions and choose appropriate aggregation functions yourself.

# %% [markdown]
# ### Q88. Analyze Sales for Region × Category.

# %% [markdown]
# ### Q89. Analyze Sales for Category × Sub-Category.

# %% [markdown]
# ### Q90. Analyze Sales for Year × Category.

# %% [markdown]
# ### Q91. Analyze Sales for Region × Shipping Mode.

# %% [markdown]
# ### Q92. Analyze Sales for Customer × Category.

# %% [markdown]
# ### Q93. Compare the number of records and total Sales for each Category.

# %% [markdown]
# ### Q94. Compare the number of records and total Sales for each Region.

# %% [markdown]
# ## 13. Pivot Table Challenges
#
# Solve these using Pandas pivot-table functionality.

# %% [markdown]
# ### Q95. Create a summary showing Category vs Region using total Sales.

# %% [markdown]
# ### Q96. Create a summary showing Year vs Category using total Sales.

# %% [markdown]
# ### Q97. Create a summary showing Region vs Shipping Mode using total Sales.

# %% [markdown]
# ### Q98. Create a summary showing Customer Segment vs Category using total Sales.

# %% [markdown]
# ## 14. Advanced Pandas Challenges
#
# These require you to combine multiple Pandas concepts. Decide the approach yourself.

# %% [markdown]
# ### Q99. Find the highest-selling category within each region based on total Sales.

# %% [markdown]
# ### Q100. Find the top 3 customers within each region based on total Sales.

# %% [markdown]
# ### Q101. Find the top-performing month for each year based on total Sales.

# %% [markdown]
# ### Q102. Find the highest-selling sub-category within each category.

# %% [markdown]
# ### Q103. Calculate each category's percentage contribution to total Sales.

# %% [markdown]
# ### Q104. Find records whose Sales are above the overall average Sales.

# %% [markdown]
# ### Q105. Find the top-selling product within each category.

# %% [markdown]
# ### Q106. Find the state with the highest total Sales within each region.

# %% [markdown]
# ### Q107. Find the customer with the highest total Sales within each segment.

# %% [markdown]
# ### Q108. For each year, find the category with the highest total Sales.

# %% [markdown]
# ## 15. Think Like a Data Analyst
#
# Now stop focusing on individual Pandas functions. Use your analysis to make business conclusions.
#
# Remember: this dataset contains **Sales but not Profit**, so your conclusions must be based only on information actually available in the dataset.

# %% [markdown]
# ### Q109. Which category should the company focus on based on Sales? Explain why.

# %% [markdown]
# ### Q110. Which category has the strongest Sales performance, and what evidence supports your conclusion?

# %% [markdown]
# ### Q111. Which region needs attention based on Sales? Explain your reasoning carefully.

# %% [markdown]
# ### Q112. Which customers are particularly valuable based on Sales and purchase activity?

# %% [markdown]
# ### Q113. Which products or sub-categories appear to need attention based on Sales patterns?

# %% [markdown]
# ### Q114. Are there noticeable changes in business Sales performance over time?

# %% [markdown]
# ### Q115. What are the 5 most important insights you discovered?

# %% [markdown]
# ### Q116. If you were presenting this analysis to the company's manager, what 5 recommendations would you make based only on the available data?

# %% [markdown]
# # 📝 Final Case Study Checklist
#
# Before submitting the notebook, check that you have:
#
# - [ ] Investigated the raw dataset
# - [ ] Identified data-quality issues
# - [ ] Performed Sales analysis
# - [ ] Used filtering and sorting
# - [ ] Used grouping and aggregation
# - [ ] Worked with dates
# - [ ] Created derived columns
# - [ ] Practiced multi-level GroupBy
# - [ ] Practiced pivot tables
# - [ ] Completed advanced Pandas challenges
# - [ ] Written business insights and recommendations
# - [ ] Avoided using unavailable fields such as Profit, Quantity, Discount, and Cost
# - [ ] Used Pandas only
#
# ## Submission
#
# When you finish, submit this notebook back to me.
#
# I will review:
# 1. Correctness of your Pandas code
# 2. Whether your approach is efficient and readable
# 3. Your understanding of the output
# 4. Your business reasoning
# 5. Interview-level explanations
# 6. Any important concepts you missed
#
# **I will not give you the solutions in advance.**
