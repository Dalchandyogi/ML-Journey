# %%
import pandas as pd

# %% [markdown]
# ### Reading Excel Files

# %%
pd.read_excel('Data Sets/college.xlsx')
# Out:
#     Roll No            Name    City Department
# 0         1  Dal Chand Yogi  Jaipur        CSE
# 1         2        Mithlesh   alwar        ECE
# 2         3          Seema     kota       MECH
# 3         4           Saroj  jaipur        CSE
# 4         5          Suresh    kota        CSE
# 5         6           Ashok   alwar        CSE
# 6         7        Rohitash  Jaipur       MECH
# 7         8          Kelash  Jaipur     CIVIAL
# 8         9          Roshan  Jaipur       MECH
# 9        10          Lakhan    kota        ECE
# 10       11           Tulsi    kota        ECE
# 11       12          Payal    alwar        ECE
# 12       13         Manisha   alwar        CSE
# 13       14          Prinka   alwar        CSE
# 14       15         Shivani   alwar        ECE

# %%
pd.read_excel('Data Sets/college.xlsx', sheet_name='teachers')
# Out:
#    TeacherID      Name  Salary
# 0          1   Sameera   40000
# 1          2    Naveen   20000
# 2          3    Deepak   10000
# 3          4    Rajesh  100000
# 4          5     Sweta   40000
# 5          6  Sikander   90000
# 6          7  Aasutosh   50000
# 7          8     Aanju   30000

# %%
pd.read_excel('Data Sets/college.xlsx', sheet_name='students')
# Out:
#     Roll No            Name    City Department
# 0         1  Dal Chand Yogi  Jaipur        CSE
# 1         2        Mithlesh   alwar        ECE
# 2         3          Seema     kota       MECH
# 3         4           Saroj  jaipur        CSE
# 4         5          Suresh    kota        CSE
# 5         6           Ashok   alwar        CSE
# 6         7        Rohitash  Jaipur       MECH
# 7         8          Kelash  Jaipur     CIVIAL
# 8         9          Roshan  Jaipur       MECH
# 9        10          Lakhan    kota        ECE
# 10       11           Tulsi    kota        ECE
# 11       12          Payal    alwar        ECE
# 12       13         Manisha   alwar        CSE
# 13       14          Prinka   alwar        CSE
# 14       15         Shivani   alwar        ECE

# %% [markdown]
# ### Reading Text Files

# %%
pd.read_csv('Data Sets/question_ans.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pd.read_csv('Data Sets/question_ans.txt')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
pd.read_csv('Data Sets/question_ans.txt', sep='\t')
# Out:
#        ArticleTitle                                           Question  \
# 0   Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 1   Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 2   Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 3   Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 4   Abraham_Lincoln                   Did his mother die of pneumonia?
# 5   Abraham_Lincoln                   Did his mother die of pneumonia?
# 6   Abraham_Lincoln      How many long was Lincoln's formal education?
# 7   Abraham_Lincoln      How many long was Lincoln's formal education?
# 8   Abraham_Lincoln       When did Lincoln begin his political career?
# 9   Abraham_Lincoln       When did Lincoln begin his political career?
# 10  Abraham_Lincoln   What did The Legal Tender Act of 1862 establish?
# 11  Abraham_Lincoln   What did The Legal Tender Act of 1862 establish?
# ...
